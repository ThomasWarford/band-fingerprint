# %%
import hdbscan
import pandas as pd
import numpy as np
# %matplotlib ipympl
import matplotlib.pyplot as plt
from sklearn import manifold
from ipywidgets import interact, Output
from IPython.display import clear_output

import sys
sys.path.append('..')
from src.band_plotters import DATA_DIRECTORY
from src.cluster_plotters import plot_cluster_ellipses, plot_groups

# %%
FINGERPRINT_NAME = "all_k_branches_histogram_-8_to_8_normed"
FINGERPRINT_LENGTH = 120
PERPLEXITY = 30
INPUT_NAME = f"{FINGERPRINT_NAME}_perplexity_{PERPLEXITY}_length_{FINGERPRINT_LENGTH}.csv"

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv(f"../fingerprints/{INPUT_NAME}", index_col="ID")
df.head()
# Out:
#       formula gen_formula  space_group  segments  flat_segments  \
# ID
# 2dm-1    IrF2         AB2          164         3              0
# 2dm-2   Ba2Sb         AB2          164         3              1
# 2dm-3     TlS          AB            2         4              4
# 2dm-4   MoCl2         AB2          166         5              4
# 2dm-6    RuI2         AB2          164         3              1
#
#        flatness_score  discovery  binary_flatness  horz_flat_seg  \
# ID
# 2dm-1        0.095102  bottom-up                0              0
# 2dm-2        0.387410  bottom-up                0              0
# 2dm-3        0.846460  bottom-up                1              3
# 2dm-4        0.713760  bottom-up                0              0
# 2dm-6        0.264930  bottom-up                0              0
#
#        exfoliation_eg  ...       112       113       114       115       116  \
# ID                     ...
# 2dm-1        0.234620  ...  0.039809  0.079618  0.119427  0.071656  0.071656
# 2dm-2        0.210650  ...  0.056936  0.067288  0.139752  0.041408  0.025880
# 2dm-3        0.095794  ...  0.090058  0.048631  0.072046  0.084654  0.117075
# 2dm-4       -0.055818  ...  0.016997  0.072238  0.044618  0.089235  0.070113
# 2dm-6        0.084831  ...  0.092379  0.115473  0.103926  0.086605  0.115473
#
#             117       118       119          fx         fy
# ID
# 2dm-1  0.151274  0.111465  0.071656  -29.415546  12.497206
# 2dm-2  0.000000  0.000000  0.000000 -115.863630 -41.305870
# 2dm-3  0.142291  0.189121  0.115274   38.001920  -1.966975
# 2dm-4  0.084986  0.093484  0.106232  -19.082489 -67.730130
# 2dm-6  0.115473  0.121247  0.150115  -53.151638 -13.686889
#
# [5 rows x 148 columns]

# %% [markdown]
# ## Cluster

# %%
fingerprint_cols = [str(i) for i in range(FINGERPRINT_LENGTH)]

# %%
clusterer = hdbscan.HDBSCAN(algorithm='best', alpha=1.0, approx_min_span_tree=True,\
                        gen_min_span_tree=False, leaf_size=40, metric='minkowski', cluster_selection_method='leaf', min_cluster_size=4, min_samples=4, p=0.2)
clusterer.fit(df[fingerprint_cols])

df["labels"] = clusterer.labels_

# %%
def view_cluster(label):
    display(df[df.labels==label].head(100))

    num_plots = len(df[df.labels==label])

    fig, ax = plt.subplots(num_plots, 1, figsize=(4, 1*num_plots))

    for i, index in enumerate(df[df.labels==label].index):
        ax[i].plot(np.linspace(0, FINGERPRINT_LENGTH, FINGERPRINT_LENGTH), df.loc[index][fingerprint_cols])
        ax[i].set_xlabel(index)
    
    
interact(view_cluster, label=(-1, len(np.unique(df.labels))-2, 1))
# Out:
# interactive(children=(IntSlider(value=17, description='label', max=35, min=-1), Output()), _dom_classes=('widg…
# <function __main__.view_cluster(label)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Example Plots
# I recommend plotting the groups before the cluster ellipses, otherwise the figure might end up having axis going from 0 to 1.

# %%
rel_id = df.groupby("relative_id").groups

# %%
lab = df.groupby("labels").groups

# %%
crosstab = pd.crosstab(df.labels, df.relative_id, values=0, aggfunc=lambda:0)
crosstab
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 crosstab = pd.crosstab(df.labels, df.relative_id, values=0, aggfunc=lambda:0)
#       2 crosstab
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:711, in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     707     kwargs = {"aggfunc": aggfunc}
#     709 # error: Argument 7 to "pivot_table" of "DataFrame" has incompatible type
#     710 # "**Dict[str, object]"; expected "Union[...]"
# --> 711 table = df.pivot_table(
#     712     "__dummy__",
#     713     index=unique_rownames,
#     714     columns=unique_colnames,
#     715     margins=margins,
#     716     margins_name=margins_name,
#     717     dropna=dropna,
#     718     **kwargs,  # type: ignore[arg-type]
#     719 )
#     721 # Post-process
#     722 if normalize is not False:
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/frame.py:9193, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9176 @Substitution("")
#    9177 @Appender(_shared_docs["pivot_table"])
#    9178 def pivot_table(
#    (...)
#    9189     sort: bool = True,
#    9190 ) -> DataFrame:
#    9191     from pandas.core.reshape.pivot import pivot_table
# -> 9193     return pivot_table(
#    9194         self,
#    9195         values=values,
#    9196         index=index,
#    9197         columns=columns,
#    9198         aggfunc=aggfunc,
#    9199         fill_value=fill_value,
#    9200         margins=margins,
#    9201         dropna=dropna,
#    9202         margins_name=margins_name,
#    9203         observed=observed,
#    9204         sort=sort,
#    9205     )
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:99, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      96     table = concat(pieces, keys=keys, axis=1)
#      97     return table.__finalize__(data, method="pivot_table")
# ---> 99 table = __internal_pivot_table(
#     100     data,
#     101     values,
#     102     index,
#     103     columns,
#     104     aggfunc,
#     105     fill_value,
#     106     margins,
#     107     dropna,
#     108     margins_name,
#     109     observed,
#     110     sort,
#     111 )
#     112 return table.__finalize__(data, method="pivot_table")
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:169, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     166     values = list(values)
#     168 grouped = data.groupby(keys, observed=observed, sort=sort, dropna=dropna)
# --> 169 agged = grouped.agg(aggfunc)
#     171 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     172     agged = agged.dropna(how="all")
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1476, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1473 # grouper specific aggregations
#    1474 if self.grouper.nkeys > 1:
#    1475     # test_groupby_as_index_series_scalar gets here with 'not self.as_index'
# -> 1476     return self._python_agg_general(func, *args, **kwargs)
#    1477 elif args or kwargs:
#    1478     # test_pass_args_kwargs gets here (with and without as_index)
#    1479     # can't return early
#    1480     result = self._aggregate_frame(func, *args, **kwargs)
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1542, in DataFrameGroupBy._python_agg_general(self, func, *args, **kwargs)
#    1540 output: dict[int, ArrayLike] = {}
#    1541 for idx, (name, ser) in enumerate(obj.items()):
# -> 1542     result = self.grouper.agg_series(ser, f)
#    1543     output[idx] = result
#    1545 res = self.obj._constructor(output)
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     843 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     844     # we can preserve a little bit more aggressively with EA dtype
#     845     #  because maybe_cast_pointwise_result will do a try/except
#     846     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     847     #  is sufficiently strict that it casts appropriately.
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     853 if preserve_dtype:
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     868 splitter = self._get_splitter(obj, axis=0)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#     874     if not initialized:
#     875         # We only do this validation on the first iteration
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1525, in DataFrameGroupBy._python_agg_general.<locals>.<lambda>(x)
#    1523     alias = com._builtin_table_alias[func]
#    1524     warn_alias_replacement(self, orig_func, alias)
# -> 1525 f = lambda x: func(x, *args, **kwargs)
#    1527 if self.ngroups == 0:
#    1528     # e.g. test_evaluate_with_empty_groups different path gets different
#    1529     #  result dtype in empty case.
#    1530     return self._python_apply_general(f, self._selected_obj, is_agg=True)
#
# TypeError: <lambda>() takes 0 positional arguments but 1 was given

# %%
from sklearn.metrics import jaccard_similarity_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from sklearn.metrics import jaccard_similarity_score
#
# ImportError: cannot import name 'jaccard_similarity_score' from 'sklearn.metrics' (/home/tw/miniforge3/envs/mphys/lib/python3.12/site-packages/sklearn/metrics/__init__.py)

# %%
for label in crosstab.index:
    for relative_id in df[df.labels==label].columns:
        label_set = set(df[df.labels==label].index)
        relative_id_set = set(df[df.relative_id==relative_id].index)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 3
#       1 for label in crosstab.index:
#       2     for relative_id in crosstab.columns:
# ----> 3         label_set = set(df[df.labels==label].index)
#       4         relative_id_set = set(df[df.relative_id==relative_id].index)
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/series.py:5791, in Series._cmp_method(self, other, op)
#    5790 def _cmp_method(self, other, op):
# -> 5791     res_name = ops.get_op_result_name(self, other)
#    5793     if isinstance(other, Series) and not self._indexed_same(other):
#    5794         raise ValueError("Can only compare identically-labeled Series objects")
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/ops/common.py:96, in get_op_result_name(left, right)
#      81 def get_op_result_name(left, right):
#      82     """
#      83     Find the appropriate name to pin to an operation result.  This result
#      84     should always be either an Index or a Series.
#    (...)
#      94         Usually a string
#      95     """
# ---> 96     if isinstance(right, (ABCSeries, ABCIndex)):
#      97         name = _maybe_match_name(left, right)
#      98     else:
#
# File ~/miniforge3/envs/mphys/lib/python3.12/site-packages/pandas/core/dtypes/generic.py:42, in create_pandas_abc_type.<locals>._instancecheck(cls, inst)
#      38     return getattr(inst, attr, "_typ") in comp
#      40 # https://github.com/python/mypy/issues/1006
#      41 # error: 'classmethod' used with a non-method
# ---> 42 @classmethod  # type: ignore[misc]
#      43 def _instancecheck(cls, inst) -> bool:
#      44     return _check(inst) and not isinstance(inst, type)
#      46 @classmethod  # type: ignore[misc]
#      47 def _subclasscheck(cls, inst) -> bool:
#      48     # Raise instead of returning False
#      49     # This is consistent with default __subclasscheck__ behavior
#
# KeyboardInterrupt:

# %%
label_set
# Out:
# {'2dm-612', '2dm-1728', '2dm-1784', '2dm-3684'}
